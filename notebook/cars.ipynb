# %% [markdown]
# # Challenge-cars

# %% [markdown]
# ![](./images/trump.jpg)

# %% [markdown]
# **Instructions**
#
# In this callenge, you will play with a new DataFrame listing cars models in order to master the basics methods of Pandas library.

# %% [markdown]
# # Cars

# %% [markdown]
# Let's pratice our new skills with a dataset listing cars models

# %% [markdown]
# **Q1** : Begin by importing pandas and numpy using the standard convention

# %%
#TODO :importing pandas and numpy using the standard convention
import pandas as pd
import numpy as np

# %% [markdown]
# **Q2**: Now load the file *../data/Automobile_data.csv* into the **DataFrame** *cars_df* and display the first lines

# %%
# ToDO: load the dataset contained in the file automobile_data.csv
# and display the first 10 lines

cars_df = pd.read_csv('../data/Automobile_data.csv')
cars_df.head(10)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
# 5          2                 ?         audi       gas        std          two
# 6          1               158         audi       gas        std         four
# 7          1                 ?         audi       gas        std         four
# 8          1               158         audi       gas      turbo         four
# 9          0                 ?         audi       gas      turbo          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# ...

# %% [markdown]
# **Q3**: Do you see any missing or strange data?
#
# Reload the automobile data into cars_df DataFrame and make sure this time to treat those strange values as NaN

# %%
# TODO: identify how the missing data is filled and replece it with NaN
# and then display again the fisrt ten lines to check it has worked
###### START ####
import os
path = os.path.join('..','data','Automobile_data.csv')
cars_df = pd.read_csv(path, na_values=['?'])
cars_df.head(10)

#### END  ####
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                NaN  alfa-romero       gas        std
# 1          3                NaN  alfa-romero       gas        std
# 2          1                NaN  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
# 5          2                NaN         audi       gas        std
# 6          1              158.0         audi       gas        std
# 7          1                NaN         audi       gas        std
# 8          1              158.0         audi       gas      turbo
# 9          0                NaN         audi       gas      turbo
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# ...

# %% [markdown]
# **Q4**. Display the last 8 rows of the DataFrame

# %%
# TODO: display the last 8 rows of cars
#### START ####

cars_df.tail(8)

#### END ####
# Out:
#      symboling  normalized-losses   make fuel-type aspiration num-of-doors  \
# 197         -1               74.0  volvo       gas        std         four
# 198         -2              103.0  volvo       gas      turbo         four
# 199         -1               74.0  volvo       gas      turbo         four
# 200         -1               95.0  volvo       gas        std         four
# 201         -1               95.0  volvo       gas      turbo         four
# 202         -1               95.0  volvo       gas        std         four
# 203         -1               95.0  volvo    diesel      turbo         four
# 204         -1               95.0  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 197      wagon          rwd           front       104.3  ...          141
# 198      sedan          rwd           front       104.3  ...          130
# ...

# %% [markdown]
# **Q6**. Retrieve the number of non null entries per column. Does the column price contain null values ?

# %%
# TODO: Print out the information of the dataframe
#### START ####

cars_df.info()

### END ###
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  164 non-null    float64
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       203 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
# Method 2

len(cars_df) - cars_df.isnull().sum()

#### END ###
# Out:
# symboling            205
# normalized-losses    164
# make                 205
# fuel-type            205
# aspiration           205
# num-of-doors         203
# body-style           205
# drive-wheels         205
# engine-location      205
# wheel-base           205
# length               205
# width                205
# height               205
# curb-weight          205
# engine-type          205
# num-of-cylinders     205
# engine-size          205
# fuel-system          205
# bore                 201
# stroke               201
# compression-ratio    205
# horsepower           203
# peak-rpm             203
# city-mpg             205
# highway-mpg          205
# price                201
# dtype: int64

# %% [markdown]
# **Q7**. Let's now seleect all the rows with a value in 'price' column, and store them it in a new DataFrame called *cars_with_price_df.
#
# What is the shape of this new DataFrame? confirm your answer using previous result.

# %%
# TODO: select the cars with a price in the cars_with_price

### START ###

cars_with_price = cars_df[cars_df['price'].notnull()]
cars_with_price.shape

### END ###
# Out:
# (201, 26)

# %% [markdown]
# **Q8**. How many distinct **constructors** exist in the dataset?

# %%
# TODO: print how many constructors( 'make') are present in the dataset
### Start ###

print(cars_df['make'].unique())

cars_df['make'].nunique()

### END ###
# Out:
# ['alfa-romero' 'audi' 'bmw' 'chevrolet' 'dodge' 'honda' 'isuzu' 'jaguar'
#  'mazda' 'mercedes-benz' 'mercury' 'mitsubishi' 'nissan' 'peugot'
#  'plymouth' 'porsche' 'renault' 'saab' 'subaru' 'toyota' 'volkswagen'
#  'volvo']
# 22

# %% [markdown]
# **Q9**. Display all the constructors that have released more than 10 models. Save those results into a new *big_makers* variable.

# %%
# TODO: which makers have more than 10 models?
### START ###

pd.DataFrame(np.unique(cars_df.make,return_counts=True))
# Out:
#             0     1    2          3      4      5      6       7      8   \
# 0  alfa-romero  audi  bmw  chevrolet  dodge  honda  isuzu  jaguar  mazda
# 1            3     7    8          3      9     13      4       3     17
#
#               9   ...      12      13        14       15       16    17  \
# 0  mercedes-benz  ...  nissan  peugot  plymouth  porsche  renault  saab
# 1              8  ...      18      11         7        5        2     6
#
#        18      19          20     21
# 0  subaru  toyota  volkswagen  volvo
# 1      12      32          12     11
#
# [2 rows x 22 columns]

# %%
# method2
cars_df['make'].value_counts()
# Out:
# toyota           32
# nissan           18
# mazda            17
# honda            13
# mitsubishi       13
# subaru           12
# volkswagen       12
# volvo            11
# peugot           11
# dodge             9
# mercedes-benz     8
# bmw               8
# audi              7
# plymouth          7
# saab              6
# porsche           5
# isuzu             4
# alfa-romero       3
# chevrolet         3
# jaguar            3
# renault           2
# mercury           1
# Name: make, dtype: int64

# %%
makers_cars = cars_df['make'].value_counts()
big_makers = makers_cars[makers_cars > 10]
big_makers
# Out:
# toyota        32
# nissan        18
# mazda         17
# honda         13
# mitsubishi    13
# subaru        12
# volkswagen    12
# volvo         11
# peugot        11
# Name: make, dtype: int64

# %% [markdown]
# **Q10**. Let's order a bit those results:
#
# - First, display those results in alphabetical order
# - Secondly, display those results by increasing value of number of models

# %%
## TODO: sort the results
### START ###

print("Alphabetical order: ")
print(big_makers.sort_index())

print("\nincreasing number of models: ")
print(big_makers.sort_values())

### END ###
# Out:
# Alphabetical order:
# honda         13
# mazda         17
# mitsubishi    13
# nissan        18
# peugot        11
# subaru        12
# toyota        32
# volkswagen    12
# volvo         11
# Name: make, dtype: int64
#
# increasing number of models:
# volvo         11
# peugot        11
# subaru        12
# volkswagen    12
# honda         13
# mitsubishi    13
# mazda         17
# nissan        18
# toyota        32
# Name: make, dtype: int64

# %% [markdown]
# **Q11**. Retrieve the following statistic:
#
# - the car with the maximum horsepower
# - the car with the minimum length
# - the mean of cars width
# - the standard deviation of cars heigth

# %%
print('maximum horsepower', cars_df['horsepower'].max())
print('minimum length', cars_df['length'].min())
print('mean of cars width', cars_df['width'].mean())
print('the standard deviation of cars heigth', cars_df['height'].std())
# Out:
# maximum horsepower 288.0
# minimum length 141.1
# mean of cars width 65.90780487804875
# the standard deviation of cars heigth 2.4435219699049044
