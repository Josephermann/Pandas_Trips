# %% [markdown]
# # PANDAS TRAINING

# %% [markdown]
# ## How do I read a tabular data file into pandas?

# %%
import pandas as pd

# %%
orders=pd.read_table('http://bit.ly/chiporders')

# %%
orders.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
pd.read_table('http://bit.ly/movieusers')
# Out:
#           1|24|M|technician|85711
# 0              2|53|F|other|94043
# 1             3|23|M|writer|32067
# 2         4|24|M|technician|43537
# 3              5|33|F|other|15213
# 4          6|42|M|executive|98101
# 5      7|57|M|administrator|91344
# 6      8|36|M|administrator|05201
# 7            9|29|M|student|01002
# 8            10|53|M|lawyer|90703
# 9             11|39|F|other|30329
# 10            12|28|F|other|06405
# 11         13|47|M|educator|29206
# 12        14|45|M|scientist|55106
# 13         15|49|F|educator|97301
# 14    16|21|M|entertainment|10309
# 15       17|30|M|programmer|06355
# 16            18|35|F|other|37212
# 17        19|40|M|librarian|02138
# 18        20|42|F|homemaker|95660
# 19           21|26|M|writer|30068
# 20           22|25|M|writer|40206
# 21           23|30|F|artist|48197
# 22           24|21|F|artist|94533
# 23         25|39|M|engineer|55107
# 24         26|49|M|engineer|21044
# 25        27|40|F|librarian|30030
# ...

# %%
users_cols=["user_id","user_age","user_gender","occupation","zip_code"]
movie_user=pd.read_table('http://bit.ly/movieusers', sep='|', header=None, names= users_cols)

# %%
movie_user.head()
# Out:
#    user_id  user_age user_gender  occupation zip_code
# 0        1        24           M  technician    85711
# 1        2        53           F       other    94043
# 2        3        23           M      writer    32067
# 3        4        24           M  technician    43537
# 4        5        33           F       other    15213

# %% [markdown]
#    ## How do I select a pandas series from a Dataframe?

# %%
ufo=pd.read_csv('http://bit.ly/uforeports')

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.City.head()
# Out:
# 0                  Ithaca
# 1             Willingboro
# 2                 Holyoke
# 3                 Abilene
# 4    New York Worlds Fair
# Name: City, dtype: object

# %%
ufo['City'].head()
# Out:
# 0                  Ithaca
# 1             Willingboro
# 2                 Holyoke
# 3                 Abilene
# 4    New York Worlds Fair
# Name: City, dtype: object

# %%
type(ufo.City)
# Out:
# pandas.core.series.Series

# %%
type(ufo)
# Out:
# pandas.core.frame.DataFrame

# %%
ufo["Colors Reported"].head(10)
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# Name: Colors Reported, dtype: object

# %%
ufo.shape
# Out:
# (18241, 5)

# %%
ufo1=ufo

# %%
union=(ufo1.City + ' , ' + ufo1.State)

# %%
ufo1['location']=union

# %%
ufo1.head(10)
# Out:
#                    City Colors Reported Shape Reported State  \
# 0                Ithaca             NaN       TRIANGLE    NY
# 1           Willingboro             NaN          OTHER    NJ
# 2               Holyoke             NaN           OVAL    CO
# 3               Abilene             NaN           DISK    KS
# 4  New York Worlds Fair             NaN          LIGHT    NY
# 5           Valley City             NaN           DISK    ND
# 6           Crater Lake             NaN         CIRCLE    CA
# 7                  Alma             NaN           DISK    MI
# 8               Eklutna             NaN          CIGAR    AK
# 9               Hubbard             NaN       CYLINDER    OR
#
#                Time                   location
# 0    6/1/1930 22:00                Ithaca , NY
# 1   6/30/1930 20:00           Willingboro , NJ
# 2   2/15/1931 14:00               Holyoke , CO
# 3    6/1/1931 13:00               Abilene , KS
# 4   4/18/1933 19:00  New York Worlds Fair , NY
# ...

# %%
ufo.to_csv('F:\\Pandas_couses\\training\\uforeports.csv')

# %%
orders.to_csv('F:\\Pandas_couses\\training\\chiporders.csv')

# %% [markdown]
# ## How do I rename columns in a pandas Dataframe?

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time  \
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
#
#                     location
# 0                Ithaca , NY
# 1           Willingboro , NJ
# 2               Holyoke , CO
# 3               Abilene , KS
# 4  New York Worlds Fair , NY

# %%
ufo.columns
# Out:
# Index(['City', 'Colors Reported', 'Shape Reported', 'State', 'Time',
#        'location'],
#       dtype='object')

# %%
ufo.rename(columns={"Colors Reported":"Colors_reported","Shape Reported":"Shape_Reported"}).head()
# Out:
#                    City Colors_reported Shape_Reported State             Time  \
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
#
#                     location
# 0                Ithaca , NY
# 1           Willingboro , NJ
# 2               Holyoke , CO
# 3               Abilene , KS
# 4  New York Worlds Fair , NY

# %%
ufo_cols=['city','colors reported', 'shape reported','state','time','location']

# %%
ufo.columns=ufo_cols

# %%
ufo.columns
# Out:
# Index(['city', 'colors reported', 'shape reported', 'state', 'time',
#        'location'],
#       dtype='object')

# %%
ufo.columns=ufo.columns.str.replace(' ','_')# we replace all the spaces with under score

# %%
ufo.columns
# Out:
# Index(['city', 'colors_reported', 'shape_reported', 'state', 'time',
#        'location'],
#       dtype='object')

# %% [markdown]
# ## How do I remove columns from pandas DataFrame?

# %%
ufo.columns
# Out:
# Index(['city', 'colors_reported', 'shape_reported', 'state', 'time',
#        'location'],
#       dtype='object')

# %%
ufo.shape
# Out:
# (18241, 6)

# %%
ufo.columns
# Out:
# Index(['city', 'colors_reported', 'shape_reported', 'state', 'time'], dtype='object')

# %%
ufo.columns # ufo.drop('location',axis=1)
# Out:
# Index(['city', 'colors_reported', 'shape_reported', 'state', 'time'], dtype='object')

# %%
ufo.drop(['city','state'], axis=1, inplace=True)

# %%
ufo.columns
# Out:
# Index(['colors_reported', 'shape_reported', 'time'], dtype='object')

# %%
ufo.head()
# Out:
#   colors_reported shape_reported             time
# 0             NaN       TRIANGLE   6/1/1930 22:00
# 1             NaN          OTHER  6/30/1930 20:00
# 2             NaN           OVAL  2/15/1931 14:00
# 3             NaN           DISK   6/1/1931 13:00
# 4             NaN          LIGHT  4/18/1933 19:00

# %%
ufo.drop([0,1], axis=0, inplace=True) # drop the first two rows

# %%
ufo.head()
# Out:
#   colors_reported shape_reported             time
# 2             NaN           OVAL  2/15/1931 14:00
# 3             NaN           DISK   6/1/1931 13:00
# 4             NaN          LIGHT  4/18/1933 19:00
# 5             NaN           DISK  9/15/1934 15:30
# 6             NaN         CIRCLE   6/15/1935 0:00

# %% [markdown]
# ## How do I sort a pandas DataFrame or Series?

# %%
movies=pd.read_csv('http://bit.ly/imdbratings')

# %%
movies.to_csv('../data/movies.csv')

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.title.sort_values()  # or movies['title'].sort_values()
# Out:
# 542                   (500) Days of Summer
# 5                             12 Angry Men
# 201                       12 Years a Slave
# 698                              127 Hours
# 110                  2001: A Space Odyssey
# 910                                   2046
# 596                               21 Grams
# 624                              25th Hour
# 708                       28 Days Later...
# 60                                3 Idiots
# 225                                 3-Iron
# 570                                    300
# 555                           3:10 to Yuma
# 427           4 Months, 3 Weeks and 2 Days
# 824                                     42
# 597                                  50/50
# 203                                  8 1/2
# 170                       A Beautiful Mind
# 941                       A Bridge Too Far
# 571                           A Bronx Tale
# 266                      A Christmas Story
# 86                      A Clockwork Orange
# ...

# %%
movies.title.sort_values(ascending=False)
# Out:
# 864                                  [Rec]
# 526                                   Zulu
# 615                             Zombieland
# 677                                 Zodiac
# 955                       Zero Dark Thirty
# 535                                  Zelig
# 280                     Young Frankenstein
# 96                                 Yojimbo
# 235                                Yip Man
# 403                             Ying xiong
# 695                      Y Tu Mama Tambien
# 871                                     X2
# 532                     X-Men: First Class
# 248             X-Men: Days of Future Past
# 954                                  X-Men
# 518                         Wreck-It Ralph
# 970                            Wonder Boys
# 65             Witness for the Prosecution
# 920                                Witness
# 483                           Withnail & I
# 270                        Wings of Desire
# 497    Willy Wonka & the Chocolate Factory
# ...

# %%
movies.title
# Out:
# 0                               The Shawshank Redemption
# 1                                          The Godfather
# 2                                 The Godfather: Part II
# 3                                        The Dark Knight
# 4                                           Pulp Fiction
# 5                                           12 Angry Men
# 6                         The Good, the Bad and the Ugly
# 7          The Lord of the Rings: The Return of the King
# 8                                       Schindler's List
# 9                                             Fight Club
# 10     The Lord of the Rings: The Fellowship of the Ring
# 11                                             Inception
# 12        Star Wars: Episode V - The Empire Strikes Back
# 13                                          Forrest Gump
# 14                 The Lord of the Rings: The Two Towers
# 15                                          Interstellar
# ...

# %%
movies.sort_values('title', ascending=False)
# Out:
#      star_rating                                title content_rating  \
# 864          7.5                                [Rec]              R
# 526          7.8                                 Zulu        UNRATED
# 615          7.7                           Zombieland              R
# 677          7.7                               Zodiac              R
# 955          7.4                     Zero Dark Thirty              R
# 535          7.8                                Zelig             PG
# 280          8.1                   Young Frankenstein             PG
# 96           8.4                              Yojimbo        UNRATED
# 235          8.1                              Yip Man              R
# 403          7.9                           Ying xiong          PG-13
# 695          7.7                    Y Tu Mama Tambien              R
# 871          7.5                                   X2          PG-13
# 532          7.8                   X-Men: First Class          PG-13
# ...

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.sort_values(['content_rating','duration'])
# Out:
#      star_rating                               title content_rating  \
# 713          7.6                     The Jungle Book       APPROVED
# 513          7.8      Invasion of the Body Snatchers       APPROVED
# 272          8.1                         The Killing       APPROVED
# 703          7.6                             Dracula       APPROVED
# 612          7.7                  A Hard Day's Night       APPROVED
# 58           8.5                      Paths of Glory       APPROVED
# 210          8.1                               Laura       APPROVED
# 656          7.7     Snow White and the Seven Dwarfs       APPROVED
# 844          7.5                           Pinocchio       APPROVED
# 233          8.1             The Night of the Hunter       APPROVED
# 287          8.1                     His Girl Friday       APPROVED
# 484          7.8       The Day the Earth Stood Still       APPROVED
# 451          7.9              Miracle on 34th Street       APPROVED
# ...

# %% [markdown]
# ## How do I aplly multiple filter criteria to a pandas DataFrame?

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies[movies.duration>=200]
# Out:
#      star_rating                                          title  \
# 2            9.1                         The Godfather: Part II
# 7            8.9  The Lord of the Rings: The Return of the King
# 17           8.7                                  Seven Samurai
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 157          8.2                             Gone with the Wind
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
# 476          7.8                                         Hamlet
# 630          7.7                                      Malcolm X
# 767          7.6                It's a Mad, Mad, Mad, Mad World
#
#     content_rating      genre  duration  \
# 2                R      Crime       200
# 7            PG-13  Adventure       201
# ...

# %%
movies[movies.genre.isin(['Crime','Drama','Action'])]
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# 5            8.9                                     12 Angry Men
# 9            8.9                                       Fight Club
# 11           8.8                                        Inception
# 12           8.8   Star Wars: Episode V - The Empire Strikes Back
# 13           8.8                                     Forrest Gump
# 16           8.7                  One Flew Over the Cuckoo's Nest
# 17           8.7                                    Seven Samurai
# 19           8.7                                        Star Wars
# ...

# %%
movies[(movies.duration>=200)&(movies.genre== 'Drama') ]
# Out:
#      star_rating               title content_rating  genre  duration  \
# 17           8.7       Seven Samurai        UNRATED  Drama       207
# 157          8.2  Gone with the Wind              G  Drama       238
# 476          7.8              Hamlet          PG-13  Drama       242
#
#                                            actors_list
# 17   [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 157  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# 476  [u'Kenneth Branagh', u'Julie Christie', u'Dere...

# %%
movies2=movies.loc[:,["genre","title"]]

# %%
movies2[movies2.genre=='Comedy']
# Out:
#       genre                                              title
# 25   Comedy                                  Life Is Beautiful
# 29   Comedy                                        City Lights
# 35   Comedy                                       Modern Times
# 48   Comedy  Dr. Strangelove or: How I Learned to Stop Worr...
# 52   Comedy                                 The Great Dictator
# 60   Comedy                                           3 Idiots
# 66   Comedy                                Munna Bhai M.B.B.S.
# 70   Comedy                                             Amelie
# 88   Comedy                                            The Kid
# 93   Comedy                        Dilwale Dulhania Le Jayenge
# 94   Comedy                                Singin' in the Rain
# 97   Comedy                                          The Sting
# 103  Comedy                                      The Apartment
# 106  Comedy                                            Snatch.
# ...

# %% [markdown]
# ## What's the best way to drop every non-numeric column from a DataFrame?

# %%
drinks=pd.read_csv('http://bit.ly/drinksbycountry')

# %%
drinks.to_csv('F:\\Pandas_couses\\training\\drinksbycountry.csv') # save data

# %%
drinks.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
import numpy as np

# %%
drinks.select_dtypes(include=[np.number]).dtypes
# Out:
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# dtype: object

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.select_dtypes(include=[np.number]).head()
# Out:
#    beer_servings  spirit_servings  wine_servings  total_litres_of_pure_alcohol
# 0              0                0              0                           0.0
# 1             89              132             54                           4.9
# 2             25                0             14                           0.7
# 3            245              138            312                          12.4
# 4            217               57             45                           5.9

# %%
drinks.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %%
drinks.describe(include='all')
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# count        193     193.000000       193.000000     193.000000
# unique       193            NaN              NaN            NaN
# top     Ethiopia            NaN              NaN            NaN
# freq           1            NaN              NaN            NaN
# mean         NaN     106.160622        80.994819      49.450777
# std          NaN     101.143103        88.284312      79.697598
# min          NaN       0.000000         0.000000       0.000000
# 25%          NaN      20.000000         4.000000       1.000000
# 50%          NaN      76.000000        56.000000       8.000000
# 75%          NaN     188.000000       128.000000      59.000000
# max          NaN     376.000000       438.000000     370.000000
#
#         total_litres_of_pure_alcohol continent
# count                     193.000000       193
# unique                           NaN         6
# top                              NaN    Africa
# ...

# %%
drinks.describe(include=['object'])
# Out:
#          country continent
# count        193       193
# unique       193         6
# top     Ethiopia    Africa
# freq           1        53

# %%
drinks.sort_values(['country','total_litres_of_pure_alcohol'],ascending=False)
# Out:
#                   country  beer_servings  spirit_servings  wine_servings  \
# 192              Zimbabwe             64               18              4
# 191                Zambia             32               19              4
# 190                 Yemen              6                0              0
# 189               Vietnam            111                2              1
# 188             Venezuela            333              100              3
# 187               Vanuatu             21               18             11
# 186            Uzbekistan             25              101              8
# 185               Uruguay            115               35            220
# 182        United Kingdom            219              126            195
# 181  United Arab Emirates             16              135              5
# 180               Ukraine            206              237             45
# 179                Uganda             45                9              0
# ...

# %% [markdown]
# ## How do I use the "axis" parameter in pandas?

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.drop('continent', axis=1).head() # columns axis
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol
# 0                           0.0
# 1                           4.9
# 2                           0.7
# 3                          12.4
# 4                           5.9

# %%
drinks.drop(0, axis=0).head() # rows axis
# Out:
#              country  beer_servings  spirit_servings  wine_servings  \
# 1            Albania             89              132             54
# 2            Algeria             25                0             14
# 3            Andorra            245              138            312
# 4             Angola            217               57             45
# 5  Antigua & Barbuda            102              128             45
#
#    total_litres_of_pure_alcohol      continent
# 1                           4.9         Europe
# 2                           0.7         Africa
# 3                          12.4         Europe
# 4                           5.9         Africa
# 5                           4.9  North America

# %%
drinks.mean()
# Out:
# beer_servings                   106.160622
# spirit_servings                  80.994819
# wine_servings                    49.450777
# total_litres_of_pure_alcohol      4.717098
# dtype: float64

# %%
drinks.mean(axis=1).head()
# Out:
# 0      0.000
# 1     69.975
# 2      9.925
# 3    176.850
# 4     81.225
# dtype: float64

# %% [markdown]
# ## How do I use string methods in pandas?

# %%
'hello'.upper()
# Out:
# 'HELLO'

# %%
orders.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
# orders.item_name.upper() don't work
orders.item_name.str.upper()  # you can use this
# Out:
# 0                CHIPS AND FRESH TOMATO SALSA
# 1                                        IZZE
# 2                            NANTUCKET NECTAR
# 3       CHIPS AND TOMATILLO-GREEN CHILI SALSA
# 4                                CHICKEN BOWL
# 5                                CHICKEN BOWL
# 6                               SIDE OF CHIPS
# 7                               STEAK BURRITO
# 8                            STEAK SOFT TACOS
# 9                               STEAK BURRITO
# 10                        CHIPS AND GUACAMOLE
# 11                       CHICKEN CRISPY TACOS
# 12                         CHICKEN SOFT TACOS
# 13                               CHICKEN BOWL
# 14                        CHIPS AND GUACAMOLE
# 15      CHIPS AND TOMATILLO-GREEN CHILI SALSA
# 16                            CHICKEN BURRITO
# 17                            CHICKEN BURRITO
# 18                                CANNED SODA
# 19                               CHICKEN BOWL
# ...

# %%
orders.item_name.str.contains('Salad').head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: item_name, dtype: bool

# %%
orders.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
orders.choice_description.str.replace('[\[\]]','') # drop "[]"
# Out:
# 0                                                     NaN
# 1                                              Clementine
# 2                                                   Apple
# 3                                                     NaN
# 4       Tomatillo-Red Chili Salsa (Hot), Black Beans, ...
# 5       Fresh Tomato Salsa (Mild), Rice, Cheese, Sour ...
# 6                                                     NaN
# 7       Tomatillo Red Chili Salsa, Fajita Vegetables, ...
# 8       Tomatillo Green Chili Salsa, Pinto Beans, Chee...
# 9       Fresh Tomato Salsa, Rice, Black Beans, Pinto B...
# 10                                                    NaN
# 11      Roasted Chili Corn Salsa, Fajita Vegetables, R...
# 12      Roasted Chili Corn Salsa, Rice, Black Beans, C...
# 13      Fresh Tomato Salsa, Fajita Vegetables, Rice, C...
# 14                                                    NaN
# 15                                                    NaN
# ...

# %% [markdown]
# # E
